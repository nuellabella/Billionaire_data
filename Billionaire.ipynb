# %%
import pandas as pd

# %%
billionaire_data_df = pd.read_csv(r"newdata.csv")

# %%
billionaire_data_df
# Out:
#                                      name  age  gender  net_worth  \
# 0                              Jeff Bezos   57    male      177.0
# 1                               Elon Musk   49    male      151.0
# 2                Bernard Arnault & family   72    male      150.0
# 3                              Bill Gates   65    male      124.0
# 4                         Mark Zuckerberg   36    male       97.0
# 5                           Warren Buffet   90    male       96.0
# 6                           Larry Ellison   76    male       93.0
# 7                              Larry Page   48    male       91.5
# 8                             Serget Brin   47    male       89.0
# 9                           Mukesh Ambani   63    male       84.5
# 10                         Amancio Ortega   85    male       77.0
# 11  Francoise Bettencourt Meyers & family   67  female       73.6
# 12                         Zhong Shanshan   66    male       68.9
# ...

# %%
billionaire_data_df.groupby("gender").count()
# Out:
#         name  age  net_worth  country  source  industry
# gender
# female     3    3          3        3       3         3
# male      22   22         22       22      22        22

# %%
billionaire_data_df.groupby("industry").count()
# Out:
#                          name  age  gender  net_worth  country  source
# industry
# Automotive                  1    1       1          1        1       1
# Fashion and Retail          7    7       7          7        7       7
# Finance and Investments     2    2       2          2        2       2
# Food and Beverage           1    1       1          1        1       1
# Media and Entertainment     1    1       1          1        1       1
# Technology                 10   10      10         10       10      10
# Telecom                     1    1       1          1        1       1
# diversified                 2    2       2          2        2       2

# %%
new_df = billionaire_data_df.sort_values(by=["age","name"], ascending = [False, False])

# %%
new_df.head()
# Out:
#                          name  age gender  net_worth        country  \
# 5               Warren Buffet   90   male       96.0  United States
# 10             Amancio Ortega   85   male       77.0          Spain
# 24       Phil Knight & family   83   male       49.9  United States
# 15  Carlos Slim Helu & family   81   male       62.8         Mexico
# 19          Michael Bloomberg   79   male       59.0  United States
#
#                source                 industry
# 5   Bershire Hathaway  Finance and Investments
# 10               Zara       Fashion and Retail
# 24               Nike       Fashion and Retail
# 15            telecom                  Telecom
# 19       Bloomberg LP  Media and Entertainment

# %%
df= new_df[["name","age"]].sort_values(by=["age","name"], ascending=[False,True])

# %%
df.head()
# Out:
#                          name  age
# 5               Warren Buffet   90
# 10             Amancio Ortega   85
# 24       Phil Knight & family   83
# 15  Carlos Slim Helu & family   81
# 19          Michael Bloomberg   79

# %%
df2=new_df[["name","net_worth"]].sort_values(by=["net_worth","name"], ascending=[False, True])

# %%
df2.head()
# Out:
#                        name  net_worth
# 0                Jeff Bezos      177.0
# 1                 Elon Musk      151.0
# 2  Bernard Arnault & family      150.0
# 3                Bill Gates      124.0
# 4           Mark Zuckerberg       97.0
